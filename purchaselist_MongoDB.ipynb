# %%
import pandas as pd

# %%
purchaselist = pd.read_csv('./data/purchaseinfo.csv')
purchaselist
# Out:
#      info_idx  product_idx payment_method             user_id  payment_total  \
# 0           1            3           신용카드          aaaaaa1234          49900
# 1           2            4          무통장입금          aaaaaa1234          49900
# 2           3            5          무통장입금          aaaaaa1234          49900
# 3           4            6           신용카드               admin          49900
# 4           5            7           신용카드               admin          49900
# ..        ...          ...            ...                 ...            ...
# 796       797           35          무통장입금               admin          49900
# 797       798           36           신용카드               admin          49900
# 798       799           36           신용카드               admin          49900
# 799       800           38           신용카드  cncomchinaTreeflex          49900
# 800       801           39           신용카드    cncompeopleOtcom          49900
#
#     recipient_info         recipient_addr  \
# ...

# %%
purchaselist2 = purchaselist[['user_id', 'purchase_product', 'payment_method', 'payment_total', 'payment_date']]
purchaselist2
# Out:
#                 user_id                        purchase_product  \
# 0            aaaaaa1234        핀턱 셔츠 롱 원피스 레이온블랙 MDOP043RNBLACK
# 1            aaaaaa1234               [쿨탠다드] 우먼즈 피케 폴로 원피스 [블랙]
# 2            aaaaaa1234              [쿨탠다드] 우먼즈 피케 폴로 원피스 [네이비]
# 3                 admin                   라이 맥시 롱 원피스 black[블랙]
# 4                 admin  여성 트위스트 셔츠 원피스 - 에스프레소 / DR254LF588495
# ..                  ...                                     ...
# 796               admin                  (W) CGC 루즈핏 피케 원피스 네이비
# 797               admin            블랙 골지 슬림핏 롱 원피스 (112571AC15)
# 798               admin            블랙 골지 슬림핏 롱 원피스 (112571AC15)
# 799  cncomchinaTreeflex                    빅 카라 트위드 자켓 드레스 (퍼플)
# 800    cncompeopleOtcom           [쿨탠다드] 우먼즈 피케 폴로 원피스 [블루 그레이]
#
#     payment_method  payment_total         payment_date
# 0             신용카드          49900  2022-04-19 23:29:00
# 1            무통장입금          49900  2022-04-19 23:29:00
# ...

# %%
purchaselist2.to_csv('./data/chatbot_dataset/purchaselist.csv', header=True, index=False, encoding="utf-8")
